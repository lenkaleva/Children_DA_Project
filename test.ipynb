# %%
x = 'hello'
# Out:
# 'hello world'

# %%
x = 'hello' 
x
# Out:
# 'hello world'

# %%
x = 'hello' 
x
# Out:
# 'hello team'

# %%
zkouska = "testovani zpusobu od Soustruha"
zkouska
# Out:
# 'testovani zpusobu od Soustruha'
